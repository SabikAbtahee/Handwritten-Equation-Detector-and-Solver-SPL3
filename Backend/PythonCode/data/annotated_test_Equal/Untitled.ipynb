# %%
import numpy as np
import cv2
from PIL import Image
# import PIL as PIL
from matplotlib import pyplot as plt
# %matplotlib inline
import os, sys
class ImageConversions:
    def openImageUsingCV(self,path):
        img = cv2.imread(path)
        return img

    def saveNumpyImage(self,path,numImg):
        cv2.imwrite(path, numImg) 

    def openImageUsingPillow(self,path):
        im = Image.open(path)
        return im

    def savePILImage(self,path,img):
        img.save(path)

    def expandShape(self,numarray,axisNumber):
        a=np.expand_dims(numarray,axis=axisNumber)
        return a 

    def plotImageUsingMATPLOTLIB(self,img):
        plt.imshow(img)
        plt.show()

    def plotImageUsingCV(self,img):
        cv2.imshow('Gray image', img)
        cv2.waitKey(0)

    def printInformation(self,obj):
        print(type(obj))
        if isinstance(obj,np.ndarray):
            print('Numpy object ')
            print('Object shape: ',obj.shape)
            print('Object size: ',obj.size)
            print('Object type: ',obj.dtype)
        elif isinstance(obj,PIL.JpegImagePlugin.JpegImageFile):
            print('Pillow object of JPEG file')
        elif isinstance(obj,PIL.PngImagePlugin.PngImageFile):
            print('Pillow object of PNG file')

    def pixelInversion0to255(self,img): # inverts image b - w or w - b
            copyImage = np.copy(img)
            copyImage[img > 175] = 0
            copyImage[img <= 175] = 255
            return copyImage

    def isTextWhite(self,img): #returns true if text white else false
        white=np.sum(img >= 127)
        black=np.sum(img < 127)
        if(white>black):
            return False
        else:
            return True

    def convertToGrayScale(self,img): #returns grayscale image
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        return gray

    def convertOnlyto255and0(self,img): # returns image to 0 and 255 image
        grayImage=self.convertToGrayScale(img)
        (thresh, blackAndWhiteImage) = cv2.threshold(grayImage, 127, 255, cv2.THRESH_BINARY)
        

        return blackAndWhiteImage
    
    def makeTextWhite(self,img):
        bwImg=self.convertOnlyto255and0(img)
        self.printInformation(bwImg)
        if(self.isTextWhite(bwImg)==False):
            whiteTextImage=self.pixelInversion0to255(bwImg)
        else:
            whiteTextImage = bwImg
        inv=self.expandShape(whiteTextImage,2)
        return inv
    
    def dilate(self,img):
        kernel = np.ones((5,5),np.uint8)
        # erosion = cv2.erode(img,kernel,iterations = 1)
        opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
        dilation = cv2.dilate(img,kernel,iterations = 1)
        return dilation
    
    def erode(self,img):
        kernel = np.ones((5,5),np.uint8)
        opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
        erosion = cv2.erode(img,kernel,iterations = 1)
#         dilation = cv2.dilate(img,kernel,iterations = 1)
        return erosion

    def resize(self,img,width,height):
        dim=(width,height)
        resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
        return resized

# %%
proces=ImageConversions()
dirs = os.listdir('./d/')
y=0
for item in dirs:
    print(item)
    #     y=y+1
    currentimg='./d/'+item
    img=proces.openImageUsingCV(currentimg) #open
#     print(img)
#     if(img):
#     print(img)
    proces.printInformation(img)
    whiteImg=proces.makeTextWhite(img) #Converted and made text white
    dilated=proces.dilate(whiteImg) #dilated
#     done=proces.makeTextWhite(dilated)
#     resized=proces.resize(dilated,wid,height) #Resized
#     done=proces.expandShape(resized,2) # wid*height*1 shaped      
    imagePath=currentimg # image path
#         print(imagePath)
    proces.saveNumpyImage(imagePath,dilated) # Saved Image
# Out:
# equ1 (2).jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (211, 1205, 3)
# Object size:  762765
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (211, 1205)
# Object size:  254255
# Object type:  uint8
# Equ1.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (88, 422, 3)
# Object size:  111408
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (88, 422)
# Object size:  37136
# Object type:  uint8
# equ10.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (260, 1674, 3)
# Object size:  1305720
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (260, 1674)
# Object size:  435240
# Object type:  uint8
# equ11.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (351, 1746, 3)
# Object size:  1838538
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (351, 1746)
# Object size:  612846
# Object type:  uint8
# equ12.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (316, 1805, 3)
# Object size:  1711140
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (316, 1805)
# Object size:  570380
# Object type:  uint8
# equ2.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (199, 1290, 3)
# Object size:  770130
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (199, 1290)
# Object size:  256710
# Object type:  uint8
# equ3.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (247, 1404, 3)
# Object size:  1040364
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (247, 1404)
# Object size:  346788
# Object type:  uint8
# equ4 (2).jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (275, 1384, 3)
# Object size:  1141800
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (275, 1384)
# Object size:  380600
# Object type:  uint8
# equ4.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (82, 543, 3)
# Object size:  133578
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (82, 543)
# Object size:  44526
# Object type:  uint8
# equ5.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (281, 1520, 3)
# Object size:  1281360
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (281, 1520)
# Object size:  427120
# Object type:  uint8
# equ6.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (201, 1574, 3)
# Object size:  949122
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (201, 1574)
# Object size:  316374
# Object type:  uint8
# equ7.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (272, 1468, 3)
# Object size:  1197888
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (272, 1468)
# Object size:  399296
# Object type:  uint8
# equ8.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (323, 1644, 3)
# Object size:  1593036
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (323, 1644)
# Object size:  531012
# Object type:  uint8
# equ9.jpg
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (378, 1583, 3)
# Object size:  1795122
# Object type:  uint8
# <class 'numpy.ndarray'>
# Numpy object
# Object shape:  (378, 1583)
# Object size:  598374
# Object type:  uint8
